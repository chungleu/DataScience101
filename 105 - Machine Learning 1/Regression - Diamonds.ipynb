# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('diamonds.csv')
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
pd.isnull(df).any()
# Out:
# carat      False
# cut        False
# color      False
# clarity    False
# depth      False
# table      False
# price      False
# x          False
# y          False
# z          False
# dtype: bool

# %%
plt.hist(df.price, bins=70, ec='black')
plt.show()

# %%
plt.hist(df.carat, bins=50, ec='black')
plt.show()

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df[(df.x == 0) | (df.y == 0) | (df.z == 0)]
# Out:
#        carat        cut color clarity  depth  table  price     x     y    z
# 2207    1.00    Premium     G     SI2   59.1   59.0   3142  6.55  6.48  0.0
# 2314    1.01    Premium     H      I1   58.1   59.0   3167  6.66  6.60  0.0
# 4791    1.10    Premium     G     SI2   63.0   59.0   3696  6.50  6.47  0.0
# 5471    1.01    Premium     F     SI2   59.2   58.0   3837  6.50  6.47  0.0
# 10167   1.50       Good     G      I1   64.0   61.0   4731  7.15  7.04  0.0
# 11182   1.07      Ideal     F     SI2   61.6   56.0   4954  0.00  6.62  0.0
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.00  0.00  0.0
# 13601   1.15      Ideal     G     VS2   59.2   56.0   5564  6.88  6.83  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.00  0.00  0.0
# 24394   2.18    Premium     H     SI2   59.4   61.0  12631  8.49  8.45  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.00  0.00  0.0
# ...

# %%
impossible_indices = df[(df.x == 0) | (df.y == 0) | (df.z == 0)].index
impossible_indices
# Out:
# Int64Index([ 2207,  2314,  4791,  5471, 10167, 11182, 11963, 13601, 15951,
#             24394, 24520, 26123, 26243, 27112, 27429, 27503, 27739, 49556,
#             49557, 51506],
#            dtype='int64')

# %%
df.drop(impossible_indices, inplace = True)

# %%
df.shape
# Out:
# (53920, 10)

# %%
df['price'].corr(df['carat'])
# Out:
# 0.9215920634723982

# %%
df.price.corr(df.x)
# Out:
# 0.8872313725276435

# %%
df.corr()
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028259  0.181646  0.921592  0.977779  0.953991  0.961048
# depth  0.028259  1.000000 -0.295733 -0.010729 -0.025017 -0.029069  0.095023
# table  0.181646 -0.295733  1.000000  0.127245  0.196097  0.184493  0.152483
# price  0.921592 -0.010729  0.127245  1.000000  0.887231  0.867864  0.868206
# x      0.977779 -0.025017  0.196097  0.887231  1.000000  0.974918  0.975435
# y      0.953991 -0.029069  0.184493  0.867864  0.974918  1.000000  0.956744
# z      0.961048  0.095023  0.152483  0.868206  0.975435  0.956744  1.000000

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(x=df.carat, y=df.price, alpha=0.05, color='royalblue')

plt.xlabel('carat')
plt.ylabel('price')

plt.show()

# %%
sns.lmplot(x='carat', y='price', data=df)

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.drop(['cut', 'color', 'clarity'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    carat  depth  table  price     x     y     z
# 0   0.23   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31   63.3   58.0    335  4.34  4.35  2.75

# %%
target = df.price
features = df.drop('price', axis=1)

# %%
target.head()
# Out:
# 0    326
# 1    326
# 2    327
# 3    334
# 4    335
# Name: price, dtype: int64

# %%
features.head()
# Out:
#    carat  depth  table     x     y     z
# 0   0.23   61.5   55.0  3.95  3.98  2.43
# 1   0.21   59.8   61.0  3.89  3.84  2.31
# 2   0.23   56.9   65.0  4.05  4.07  2.31
# 3   0.29   62.4   58.0  4.20  4.23  2.63
# 4   0.31   63.3   58.0  4.34  4.35  2.75

# %% [markdown]
# ## Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=42)

# %%
X_train.shape
# Out:
# (40440, 6)

# %%
len(X_train)/len(features)
# Out:
# 0.75

# %%
regr = LinearRegression()

# %%
model = regr.fit(X_train, y_train)

# %%
features.columns
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %%
model.predict([[1.5, 45, 45, 4, 4, 4]])
# Out:
# array([16483.29434455])

# %%
predicted = model.predict(X_train)
predicted
# Out:
# array([4383.13583884, 4308.36262924, 6816.98846452, ..., 1019.90521314,
#        4165.38096923, 6746.16295917])

# %%
model.score(X_train, y_train)
# Out:
# 0.8570114474263146

# %%
model.score(X_test, y_test)
# Out:
# 0.8655456535924584

# %%
print('Training data correlation:', model.score(X_train, y_train))
print('Test data correlation:', model.score(X_test, y_test))
# Out:
# Training data correlation: 0.8570114474263146
# Test data correlation: 0.8655456535924584

# %%
import numpy as np

# %%
plt.figure(figsize=(15,8))

plt.scatter(x=y_train, y=predicted, alpha=0.1, color='purple')

plt.plot(np.unique(y_train), np.poly1d(np.polyfit(y_train, predicted, 1))(np.unique(y_train)), color='royalblue')

plt.xlabel('Actual prices')
plt.ylabel('Predicted prices')

plt.show()

# %%
mse = mean_squared_error(y_train, predicted)

# %%
import math
math.sqrt(mse)
# Out:
# 1510.3137308466012

# %% [markdown]
# ### Ridge Regression
# A way to 'regularise' our model. Adds a penalty as the model complexity increases <br>
# Minimises the impact of overfitting by (applying weighted) penalties parameters in complex models

# %%
from sklearn.linear_model import Ridge

# %%
ridge_regr = Ridge(alpha=1.0)

# %%
ridge_model = ridge_regr.fit(X_train, y_train)

# %%
ridge_predicted = ridge_model.predict(X_train)
ridge_predicted
# Out:
# array([4385.77426218, 4311.03393066, 6817.33522746, ..., 1019.44300776,
#        4167.71723098, 6747.71696958])

# %%
plt.figure(figsize=(15,8))

plt.scatter(x=y_train, y=ridge_predicted, alpha=0.1, color='purple')

plt.plot(np.unique(y_train), np.poly1d(np.polyfit(y_train, ridge_predicted, 1))(np.unique(y_train)), color='royalblue')

plt.xlabel('Actual prices')
plt.ylabel('Ridge Predicted prices')

plt.show()

# %%
print('Linear Regression Score on Training Data:', model.score(X_train, y_train))
print('Linear Regression Score on Test Data:', model.score(X_train, y_train))
print('Ridge Regression Score on Training Data:', ridge_model.score(X_train, y_train))
print('Ridge Regression Score on Test Data:', ridge_model.score(X_train, y_train))
# Out:
# Linear Regression Score on Training Data: 0.8570114474263146
# Linear Regression Score on Test Data: 0.8570114474263146
# Ridge Regression Score on Training Data: 0.8570109231328904
# Ridge Regression Score on Test Data: 0.8570109231328904

# %% [markdown]
# ### Polynomial

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
degrees = 2

# %%
X_poly = PolynomialFeatures(degree=degrees).fit_transform(X_train)

# %%
X_poly_test = PolynomialFeatures(degree=degrees).fit_transform(X_test)

# %%
X_poly_test.shape
# Out:
# (13480, 28)

# %%
y_test.shape
# Out:
# (13480,)

# %%
regr2 = LinearRegression()
regr2.fit(X_poly, y_train)
regr2.score(X_poly, y_train)
# Out:
# 0.8771966736517326

# %%
print('Linear Regression Score on Training Data:', model.score(X_train, y_train))
print('Linear Regression Score on Test Data:', model.score(X_test, y_test))
print('Ridge Regression Score on Training Data:', ridge_model.score(X_train, y_train))
print('Ridge Regression Score on Test Data:', ridge_model.score(X_test, y_test))
print('Polynomial Regression Score on Training Data:', regr2.score(X_poly, y_train))
print('Polynomial Regression Score on Test Data:', regr2.score(X_poly_test, y_test))
# Out:
# Linear Regression Score on Training Data: 0.8570114474263146
# Linear Regression Score on Test Data: 0.8655456535924584
# Ridge Regression Score on Training Data: 0.8570109231328904
# Ridge Regression Score on Test Data: 0.8655915129762481
# Polynomial Regression Score on Training Data: 0.8771966736517326
# Polynomial Regression Score on Test Data: 0.4560103335199769

# %% [markdown]
# ### Polynomial - Make Pipeline

# %%
from sklearn.pipeline import make_pipeline

# %%
poly_regr = make_pipeline(PolynomialFeatures(degrees), LinearRegression())

# %%
poly_regr.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('polynomialfeatures',
#                  PolynomialFeatures(degree=2, include_bias=True,
#                                     interaction_only=False, order='C')),
#                 ('linearregression',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %%
print(poly_regr.score(X_train, y_train))
print(poly_regr.score(X_test, y_test))
# Out:
# 0.8771966736517326
# 0.4560103335199769

# %%
poly_predicted = poly_regr.predict(X_test)
poly_predicted
# Out:
# array([  685.42723605,  8553.49036258,  9438.1463543 , ...,
#         8213.75636627, 16559.91377538,   752.76636255])

# %% [markdown]
# # Ideas for Iteration

# %% [markdown]
# - Depth and Table (drop. transform)
# - Ridge regression instead?
# - Polynomial regression?
# - One hot encoding. Get_dummies()
